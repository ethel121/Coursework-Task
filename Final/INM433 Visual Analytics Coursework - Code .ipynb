# %% [markdown]
# #### Hoi Ting Ethel Cheung

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## Data Preparation

# %%
#Load and inspect the datasets
olist_customers = pd.read_csv("olist_customers_dataset.csv")
olist_geolocation = pd.read_csv("olist_geolocation_dataset.csv")
olist_order_items = pd.read_csv("olist_order_items_dataset.csv")
olist_order_payments = pd.read_csv("olist_order_payments_dataset.csv")
olist_order_reviews = pd.read_csv("olist_order_reviews_dataset.csv")
olist_orders = pd.read_csv("olist_orders_dataset.csv")
olist_products = pd.read_csv("olist_products_dataset.csv")
olist_sellers = pd.read_csv("olist_sellers_dataset.csv")
product_category_name = pd.read_csv("product_category_name_translation.csv")

# %%
olist_customers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
olist_geolocation
# Out:
#          customer_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                            1037       -23.545621       -46.639292
# 1                            1046       -23.546081       -46.644820
# 2                            1046       -23.546129       -46.642951
# 3                            1041       -23.544392       -46.639499
# 4                            1035       -23.541578       -46.641607
# ...                           ...              ...              ...
# 1000158                     99950       -28.068639       -52.010705
# 1000159                     99900       -27.877125       -52.224882
# 1000160                     99950       -28.071855       -52.014716
# 1000161                     99980       -28.388932       -51.846871
# 1000162                     99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# 1              sao paulo                SP
# ...

# %%
olist_order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
olist_order_payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
olist_order_reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99995  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99996  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99997  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99998  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 99999  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
olist_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
olist_products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
olist_sellers
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
product_category_name
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
olist_products_en = olist_products.merge(product_category_name, on='product_category_name', how='left')
olist_products_en
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
olist_orders_merge = olist_orders.merge(olist_order_items, on='order_id', how='left')
olist_orders_merge
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 113420  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 113421  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 113422  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 113423  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 113424  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
olist_orders_merge = olist_orders_merge.merge(olist_products_en, on='product_id', how='left')
olist_orders_merge
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 113420  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 113421  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 113422  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 113423  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 113424  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
olist_orders_merge = olist_orders_merge.merge(olist_customers, on='customer_id', how='left')
olist_orders_merge
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                  ...                               ...
# 113420  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 113421  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 113422  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 113423  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 113424  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
olist_orders_merge = olist_orders_merge.merge(olist_geolocation, on='customer_zip_code_prefix', how='left')
olist_orders_merge
# Out:
#                                   order_id                       customer_id  \
# 0         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 4         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# ...                                    ...                               ...
# 17313736  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 17313737  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 17313738  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 17313739  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 17313740  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# ...

# %%
olist_orders_merge = olist_orders_merge.merge(olist_order_payments, on='order_id', how='left')
olist_orders_merge
# Out:
#                                   order_id                       customer_id  \
# 0         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 4         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# ...                                    ...                               ...
# 18079636  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 18079637  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 18079638  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 18079639  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# 18079640  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# ...

# %% [markdown]
# #### Removing duplicated rows

# %%
olist_orders_merge = olist_orders_merge.drop_duplicates(subset = 'order_id', keep = 'first')
olist_orders_merge
# Out:
#                                   order_id                       customer_id  \
# 0         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 72        53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 91        47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 116       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 134       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                    ...                               ...
# 18079294  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 18079362  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 18079412  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 18079442  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 18079496  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# ...

# %% [markdown]
# After removing duplicated rows, the number of rows reduced to 99,441 rows from 17,313,741 rows

# %% [markdown]
# #### Removing unnecessary columns

# %%
#Remove unnecessary columns
print(olist_orders_merge.columns.tolist()) #Display all columns
# Out:
# ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value', 'product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm', 'product_category_name_english', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state', 'geolocation_lat', 'geolocation_lng', 'geolocation_city', 'geolocation_state', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value']

# %%
olist_orders_merge_droppedcol=olist_orders_merge.drop(['order_item_id', 'product_id', 'seller_id', 'order_approved_at','order_delivered_carrier_date','shipping_limit_date', 'product_category_name', 'customer_zip_code_prefix','customer_unique_id', 'geolocation_state', 'geolocation_city', 'product_weight_g', 'product_length_cm' ,'product_height_cm', 'product_width_cm','price'], axis=1)

# %% [markdown]
# #### Filling Missing Values

# %%
#Insepct missing values 
#Find the counts of missing values in each column by subtracting number of non-missing values for each columns from the total number of rows
olist_orders_merge_droppedcol.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# freight_value                     775
# product_name_lenght              2191
# product_description_lenght       2191
# product_photos_qty               2191
# product_category_name_english    2212
# customer_city                       0
# customer_state                      0
# geolocation_lat                   278
# geolocation_lng                   278
# payment_sequential                  1
# payment_type                        1
# payment_installments                1
# payment_value                       1
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(10,10)) 

sns.heatmap(olist_orders_merge_droppedcol.isnull(), cbar=False)

# %% [markdown]
# From this heatmap of missing values, we noticed that the missing values are distributed evenly, meaning it is missing completely at random.
#
# Here we decided to drop the rows with missing values since we have a large dataset. This is a commonly used approach to handle null values.
# This method is also more preferred since complete removal of data with missing values could result in robust and highly accurate model.

# %%
olist_orders_merge_dropna = olist_orders_merge_droppedcol.dropna()
olist_orders_merge_dropna
# Out:
#                                   order_id                       customer_id  \
# 0         e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 72        53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 91        47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 116       949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 134       ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                    ...                               ...
# 18079294  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 18079362  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 18079412  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 18079442  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 18079496  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
# ...

# %%
olist_orders_merge_dropna.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# freight_value                    0
# product_name_lenght              0
# product_description_lenght       0
# product_photos_qty               0
# product_category_name_english    0
# customer_city                    0
# customer_state                   0
# geolocation_lat                  0
# geolocation_lng                  0
# payment_sequential               0
# payment_type                     0
# payment_installments             0
# payment_value                    0
# dtype: int64

# %% [markdown]
# #### Handling Outliers

# %%
print(olist_orders_merge_dropna.dtypes)
# Out:
# order_id                          object
# customer_id                       object
# order_status                      object
# order_purchase_timestamp          object
# order_delivered_customer_date     object
# order_estimated_delivery_date     object
# freight_value                    float64
# product_name_lenght              float64
# product_description_lenght       float64
# product_photos_qty               float64
# product_category_name_english     object
# customer_city                     object
# customer_state                    object
# geolocation_lat                  float64
# geolocation_lng                  float64
# payment_sequential               float64
# payment_type                      object
# payment_installments             float64
# payment_value                    float64
# dtype: object

# %%
#Plotting the numerical variables with boxplots
import matplotlib.pyplot as plt

sns.set_style("darkgrid")
fig = plt.figure(figsize=(10,10))

sns.boxplot(y='freight_value',data=olist_orders_merge_dropna)

# %%
fig = plt.figure(figsize=(10,10))
sns.boxplot(y='product_name_lenght',data=olist_orders_merge_dropna)

# %%
fig = plt.figure(figsize=(10,10))
sns.boxplot(y='product_description_lenght',data=olist_orders_merge_dropna)

# %%
fig = plt.figure(figsize=(10,10))
sns.boxplot(y='product_photos_qty',data=olist_orders_merge_dropna)

# %%
fig = plt.figure(figsize=(10,10))
sns.boxplot(y='payment_sequential',data=olist_orders_merge_dropna)

# %%
fig = plt.figure(figsize=(10,10))
sns.boxplot(y='payment_installments',data=olist_orders_merge_dropna)

# %%
fig = plt.figure(figsize=(10,10))
sns.boxplot(y='payment_value',data=olist_orders_merge_dropna)

# %% [markdown]
# After visualising the numerical columns with boxplot, we have identified that all the columns contain outliers. However, we have decided not to remove them after inspecting the rows of outliers as removing them might lose interesting findings and useful information. For example, the outliers in 'payment_value' may imply that the e-commerce store has certain VIPs that have very high spending power, the outliers in 'payment_sequential' may help us detect fraud payment etc.

# %%
olist_orders_merge_dropna.shape
# Out:
# (94838, 19)

# %% [markdown]
# Now, we will inspect the dataset of customer reviews.

# %%
#Shape of the dataset
olist_order_reviews.shape
# Out:
# (100000, 7)

# %%
#Removing unnecessary columns
olist_order_reviews_droppedcol=olist_order_reviews.drop(['review_creation_date','review_answer_timestamp'],axis=1)

# %%
print(olist_order_reviews_droppedcol.dtypes)
# Out:
# review_id                 object
# order_id                  object
# review_score               int64
# review_comment_title      object
# review_comment_message    object
# dtype: object

# %%
#Inspecting Missing Values
olist_order_reviews_droppedcol.isnull().sum()
# Out:
# review_id                     0
# order_id                      0
# review_score                  0
# review_comment_title      88285
# review_comment_message    58247
# dtype: int64

# %% [markdown]
# From the data above, we noticed that around 88% of the customers did not give a title to their review and 58% of customers did not leave a comment for their orders.

# %%
#Visualise the missing values
fig, ax = plt.subplots(figsize=(10,10)) 

sns.heatmap(olist_order_reviews.isnull(), cbar=False)

# %% [markdown]
# We can see that the missing values are missing completely at random from the plot because the values are distributed evenly across all orders.
#
# Hence, we will be removing all the rows with no comment because the main purpose of this research paper is to analyse customer reviews and we will then impute the missing values of 'review_comment_title' as empty string.

# %%
#Removing rows with missing value in column 'review_comment_message'
olist_order_reviews_dropna = olist_order_reviews.dropna(subset=['review_comment_message'])
olist_order_reviews_dropna.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       31767
# review_comment_message         0
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
##Filling in missing values
olist_order_reviews_dropna = olist_order_reviews_dropna.fillna(value='')
olist_order_reviews_dropna.isnull().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %%
olist_order_reviews_dropna.shape
# Out:
# (41753, 7)

# %%
#Exporting the dataset to csv file for analysis on tableau
olist_orders_merge_dropna.to_csv('olist_orders_merge_dropna.csv')

# %%
olist_order_reviews_dropna.to_csv('olist_order_reviews_dropna.csv')

# %% [markdown]
# ## Analysing Customer Reviews

# %% [markdown]
# We will be using Python to analyse the customer reviews, specifically the columns 'review_comment_title' and 'review_comment_message' because we would like to use a translation function in Python to translate the reviews from Portugese to English.

# %%
import re, nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS

#defining stopwords
stop_words = set(stopwords.words('portuguese'))

comments = []

for words in olist_order_reviews_dropna['review_comment_message']:
    only_letters = re.sub("[^a-zA-Z]", " ",words)
    tokens = nltk.word_tokenize(only_letters) #Divide the sentences into smaller parts
    lower_case = [l.lower() for l in tokens] #convert all letters to lower case for consistency
    filtered_result = list(filter(lambda l: l not in stop_words, lower_case))
    comments.append(' '.join(filtered_result))
    
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

#Translating the text from Portugese to English
from google_trans_new import google_translator
translator = google_translator()

# %% [markdown]
# #### Analysing text reviews

# %%
# Using CountVectorizer to get the most important word
co_1 = CountVectorizer(ngram_range=(1,1))
counts = co_1.fit_transform(comments)
important_word = pd.DataFrame(counts.sum(axis=0),columns=co_1.get_feature_names()).T.sort_values(0,ascending=False).head(50)

# Next, we reset the index, rename the columns and apply the translate module to get the english translations 
important_word=important_word.reset_index()
important_word.rename(columns={'index':'word',0:'frequency'},inplace=True)

important_word['english_translation'] = important_word['word'].apply(translator.translate)
important_word
# Out:
#          word  frequency english_translation
# 0     produto      18866            product
# 1       prazo       8543               term
# 2     entrega       6683           delivery
# 3       antes       5655             before
# 4      chegou       5643        has arrived
# 5      recebi       5464         I received
# 6         bom       4637               good
# 7   recomendo       4362        I recommend
# 8    entregue       3899          delivered
# 9        veio       3362               came
# 10        bem       3139               good
# 11    comprei       2884           I bought
# 12  qualidade       2824            quality
# 13       loja       2467              store
# 14      ainda       2403              still
# 15       tudo       2361                all
# 16     compra       2292           purchase
# 17     gostei       1918           liked it
# 18       timo       1840               Timo
# 19         at       1832                 at
# ...

# %%
#Visualizing with Wordcloud
wordcloud1 = WordCloud(colormap="tab20", background_color='white',max_words=100).generate(' '.join(important_word['english_translation']))
plt.axis('off')
plt.imshow(wordcloud1)

# %%
# Using CountVectorizer to get the most important 2-gram
co_2 = CountVectorizer(ngram_range=(2,2))
counts = co_2.fit_transform(comments)
important_2_gram = pd.DataFrame(counts.sum(axis=0),columns=co_2.get_feature_names()).T.sort_values(0,ascending=False).head(50)

# Next, we reset the index, rename the columns and apply the translate module to get the english translations 
important_2_gram=important_2_gram.reset_index()
important_2_gram.rename(columns={'index':'2-gram',0:'frequency'},inplace=True)

important_2_gram['english_translation'] = important_2_gram['2-gram'].apply(translator.translate)
important_2_gram
# Out:
#                2-gram  frequency  english_translation
# 0         antes prazo       4207     before deadline
# 1      recebi produto       1942  I received product
# 2      produto chegou       1720     product arrived
# 3    produto entregue       1616   product delivered
# 4        chegou antes       1465      arrived before
# 5        dentro prazo       1092         within term
# 6           bem antes        973         well before
# 7            parab ns        950            parab ns
# 8        entrega pida        900        delivery ask
# 9         produto bom        883        good product
# 10       produto veio        775        product came
# 11     entregue antes        732    delivered before
# 12      prazo entrega        684       delivery time
# 13       bem embalado        654         well packed
# 14       timo produto        613       great product
# 15    super recomendo        608     super recommend
# 16         chegou bem        551        arrived well
# ...

# %%
#Visualizing with Wordcloud
wordcloud2 = WordCloud(colormap="tab20", background_color='white',max_words=200).generate(";".join(important_2_gram['english_translation']).replace(" ", "_"))
plt.figure(figsize=(8, 5))
plt.imshow(wordcloud2)
plt.axis("off")
plt.show()

# %%
# Using CountVectorizer to get the most important 3-gram
co_3 = CountVectorizer(ngram_range=(3,3))
counts = co_3.fit_transform(comments)
important_3_gram = pd.DataFrame(counts.sum(axis=0),columns=co_3.get_feature_names()).T.sort_values(0,ascending=False).head(30)

# Next, we reset the index, rename the columns and apply the translate module to get the english translations 
important_3_gram=important_3_gram.reset_index()
important_3_gram.rename(columns={'index':'3-gram',0:'frequency'},inplace=True)

important_3_gram['english_translation'] = important_3_gram['3-gram'].apply(translator.translate)
important_3_gram
# Out:
#                      3-gram  frequency             english_translation
# 0        chegou antes prazo       1112        arrived before deadline
# 1           bem antes prazo        708               well before term
# 2      entregue antes prazo        608      delivered before deadline
# 3      produto chegou antes        448         product arrived before
# 4       entrega antes prazo        433       delivery before deadline
# 5          chegou bem antes        417            arrived well before
# 6    produto entregue antes        374       product delivered before
# 7        entrega super pida        297             super delivery ask
# 8      antes prazo previsto        287       before expected deadline
# 9      ainda recebi produto        261       I still received product
# 10   produto tima qualidade        257          great quality product
# 11    produto boa qualidade        234           good quality product
# ...

# %%
#Visualizing with Wordcloud
wordcloud3 = WordCloud(colormap="tab20", background_color='white',max_words=200).generate(";".join(important_3_gram['english_translation']).replace(" ", "_"))
plt.figure(figsize=(8, 5))
plt.imshow(wordcloud3)
plt.axis("off")
plt.show()

# %% [markdown]
# #### Analysing review titles

# %%
comments_titles = []

for words in review_data_title:
    only_letters = re.sub("[^a-zA-Z]", " ",words)
    tokens = nltk.word_tokenize(only_letters)
    lower_case = [l.lower() for l in tokens] 
    filtered_result = list(filter(lambda l: l not in stop_words, lower_case))
    
    comments_titles.append(' '.join(filtered_result))

# %%
# Using CountVectorizer to get the most important word
co_1 = CountVectorizer(ngram_range=(1,1))
counts = co_1.fit_transform(comments_titles)
important_word_title = pd.DataFrame(counts.sum(axis=0),columns=co_1.get_feature_names()).T.sort_values(0,ascending=False).head(50)

# Next, we reset the index, rename the columns and apply the translate module to get the english translations 
important_word_title=important_word_title.reset_index()
important_word_title.rename(columns={'index':'word',0:'frequency'},inplace=True)

important_word_title['english_translation'] = important_word_title['word'].apply(translator.translate)
important_word_title
# Out:
#            word  frequency english_translation
# 0     recomendo       2085        I recommend
# 1       produto       1327            product
# 2           bom       1321               good
# 3         super        901              super
# 4          timo        730               Timo
# 5     excelente        665          Excellent
# 6       entrega        544           delivery
# 7         otimo        369              great
# 8        recebi        302         I received
# 9           boa        273               good
# 10         tima        218               team
# 11         tudo        192                all
# 12     entregue        183          delivered
# 13  recomendado        180        recommended
# 14           ok        158                 ok
# 15       compra        152           purchase
# 16        prazo        150               term
# 17         loja        133              store
# 18         pida        132                ask
# ...

# %%
#Visualizing with Wordcloud
wordcloud4 = WordCloud(colormap="tab20", background_color='white',max_words=100).generate(' '.join(important_word_title['english_translation']))
plt.axis('off')
plt.imshow(wordcloud4)

# %%
# Using CountVectorizer to get the most important 2-gram
co_2 = CountVectorizer(ngram_range=(2,2))
counts = co_2.fit_transform(comments_titles)
important_2_gram_title = pd.DataFrame(counts.sum(axis=0),columns=co_2.get_feature_names()).T.sort_values(0,ascending=False).head(50)

# Next, we reset the index, rename the columns and apply the translate module to get the english translations 
important_2_gram_title=important_2_gram_title.reset_index()
important_2_gram_title.rename(columns={'index':'2-gram',0:'frequency'},inplace=True)

important_2_gram_title['english_translation'] = important_2_gram_title['2-gram'].apply(translator.translate)
important_2_gram_title
# Out:
#                 2-gram  frequency   english_translation
# 0      super recomendo        681      super recommend
# 1       recebi produto        131   I received product
# 2         timo produto        103        great product
# 3    super recomendado        103    super recommended
# 4     produto entregue        103    product delivered
# 5         entrega pida         92         delivery ask
# 6          bom produto         76         good product
# 7           tudo certo         76            all right
# 8       produto errado         74        wrong product
# 9          produto bom         66         good product
# 10     produto defeito         51       defect product
# 11         antes prazo         48      before deadline
# 12             rel gio         46              rel thu
# 13             tudo ok         45     everything is OK
# 14            parab ns         38             parab ns
# 15   excelente produto         37    excellent product
# ...

# %%
#Visualizing with Wordcloud
wordcloud5 = WordCloud(colormap="tab20", background_color='white',max_words=200).generate(";".join(important_2_gram_title['english_translation']).replace(" ", "_"))
plt.figure(figsize=(8, 5))
plt.imshow(wordcloud5)
plt.axis("off")
plt.show()

# %%
# Using CountVectorizer to get the most important 3-gram
co_3 = CountVectorizer(ngram_range=(3,3))
counts = co_3.fit_transform(comments_titles)
important_3_gram_title = pd.DataFrame(counts.sum(axis=0),columns=co_3.get_feature_names()).T.sort_values(0,ascending=False).head(50)

# Next, we reset the index, rename the columns and apply the translate module to get the english translations 
important_3_gram_title=important_3_gram_title.reset_index()
important_3_gram_title.rename(columns={'index':'3-gram',0:'frequency'},inplace=True)

important_3_gram_title['english_translation'] = important_3_gram_title['3-gram'].apply(translator.translate)
important_3_gram_title
# Out:
#                       3-gram  frequency             english_translation
# 0         entrega super pida         27             super delivery ask
# 1        entrega antes prazo         15       delivery before deadline
# 2            custo benef cio         12                   cost benefit
# 3         chegou antes prazo         11        arrived before deadline
# 4         nao recebi produto         11  I did not recieve the product
# 5      produto boa qualidade          8           good quality product
# 6     produto entregue prazo          8      product delivered on time
# 7        produto veio errado          7             product came wrong
# 8       produto veio defeito          7            product came defect
# 9       produto nao entregue          7          product not delivered
# 10       ainda recebi produt          6          I still received prod
# 11      entrega super rapida          6            Super fast delivery
# ...

# %%
#Visualizing with Wordcloud
wordcloud6 = WordCloud(colormap="tab20", background_color='white',max_words=200).generate(";".join(important_3_gram_title['english_translation']).replace(" ", "_"))
plt.figure(figsize=(8, 5))
plt.imshow(wordcloud6)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Sentiment Analysis

# %% [markdown]
# We will be mapping the ratings to 1 = Positive Review for review_score >3 and 0 = Negative Review for review_score<3 and removing neutral reviews (review_score=3).

# %%
# Mapping the ratings
olist_order_reviews_dropna['Sentiment_rating'] = np.where(olist_order_reviews_dropna.review_score > 3,1,0)

# Removing neutral reviews 
olist_order_reviews_dropna = olist_order_reviews_dropna[olist_order_reviews_dropna.review_score != 3]

# Printing the counts of each class
olist_order_reviews_dropna['Sentiment_rating'].value_counts()
# Out:
# 1    26680
# 0    11408
# Name: Sentiment_rating, dtype: int64

# %% [markdown]
# 70% of sentiments are classified as positive and 30% of sentiments are classified as negative

# %%
olist_order_reviews_dropna.head(10)
# Out:
#                            review_id                          order_id  \
# 3   e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4   f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 9   8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 12  4b49719c8a200003f700d3d986ea1a19  9d6f15f95d01e79bd1349cc208361f09
# 15  3948b09f7c818e2d86c9a546758b2335  e51478e7e277a83743b6f9991dbfa3fb
# 16  9314d6f9799f5bfba510cc7bcd468c01  0dacf04c5ad59fd5a0cc1faa07c34e39
# 19  373cbeecea8286a2b66c97b1b157ec46  583174fbe37d3d5f0d6661be3aad1786
# 22  d21bbc789670eab777d27372ab9094cc  4fc44d78867142c627497b60a7e0228a
# 24  0e0190b9db53b689b285d3f3916f8441  79832b7cb59ac6f887088ffd686e1d5e
# 27  fe3db7c069d694bab50cc43463f91608  2ca73e2ff9e3a186ad1e1ffb9b1d9c10
#
#     review_score     review_comment_title  \
# 3              5
# 4              5
# 9              4                recomendo
# 12             4
# 15             5          Super recomendo
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
comments =[]

stop_words = set(stopwords.words('portuguese'))

for words in olist_order_reviews_dropna['review_comment_message']:
    only_letters = re.sub("[^a-zA-Z]", " ",words)
    tokens = nltk.word_tokenize(only_letters) #Divide the sentences into smaller parts
    lower_case = [l.lower() for l in tokens] #convert all letters to lower case for consistency
    filtered_result = list(filter(lambda l: l not in stop_words, lower_case))
    comments.append(' '.join(filtered_result))

count_vect = CountVectorizer(stop_words =set(stopwords.words('portuguese')),
                             ngram_range=(1,4)) 

count_vect_comments = count_vect.fit_transform(comments)
count_vect_comments
# Out:
# <38088x422326 sparse matrix of type '<class 'numpy.int64'>'
# 	with 870129 stored elements in Compressed Sparse Row format>

# %%
#Split the dataset into training and testing dataset
X_train, X_test, y_train, y_test= train_test_split(count_vect_comments,
                                                                    olist_order_reviews_dropna['Sentiment_rating'],
                                                                    test_size = 0.3,
                                                                    random_state = 42)

# %%
y_test.value_counts()/y_test.shape[0]
# Out:
# 1    0.698434
# 0    0.301566
# Name: Sentiment_rating, dtype: float64

# %% [markdown]
# 69.8% of sentiments are classified as positive and 30.2% of sentiments are classified as negative

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

# %%
# Defining and training the model
lr = LogisticRegression(max_iter=150)
lr.fit(X_train, y_train)

# Predicting the results
test_pred = lr.predict(X_test)

print("F1 score: ", f1_score(y_test,test_pred))
# Out:
# F1 score:  0.9410299520518088

# %%
#predicted values of Y labels
pred_train = lr.predict(X_train)
pred_test = lr.predict(X_test)

from sklearn.metrics import confusion_matrix

cf = confusion_matrix(y_test,pred_test)

#plot confusion matrix
plt.figure(figsize=(10,10))
sns.heatmap(cf/np.sum(cf), annot=True,fmt='.2%', cmap='Reds')
plt.show()

# %% [markdown]
# #### Top 20 Most important words with Positive sentiments

# %%
lr_weights = pd.DataFrame(list(zip(count_vect.get_feature_names(),
                                   lr.coef_[0])), 
                          columns= ['words','weights'])

Positive_sentiments = pd.DataFrame(lr_weights.sort_values(['weights'], ascending = False)[:20])

# %%
Positive_sentiments['english_translation'] = Positive_sentiments['words'].apply(translator.translate)
Positive_sentiments
# Out:
#                words   weights english_translation
# 166120     excelente  3.256390          Excellent
# 389525          timo  3.172105               Timo
# 275765          pido  2.694402              I ask
# 255753         otimo  2.595993              great
# 17056           amei  2.497577               Amei
# 358938    satisfeito  2.446504            pleased
# 274716          pida  2.442544                ask
# 272397      perfeito  2.415608            Perfect
# 5972          adorei  2.352800         I loved it
# 215217         lindo  2.319936             pretty
# 45931            bom  2.318323               good
# 255509         otima  2.099878              great
# 388676          tima  2.055728               team
# 358400    satisfeita  1.914937          satisfied
# 250613      obrigada  1.884093             thanks
# 252397            ok  1.859842                 ok
# 62098       certinho  1.834610         just right
# 100770  corretamente  1.809469          correctly
# ...

# %%
#### Top 20 Most important words with Negative sentiments

# %%
Negative_Sentiments = pd.DataFrame(lr_weights.sort_values(['weights'], ascending = False)[-20:])
Negative_Sentiments['english_translation'] = Negative_Sentiments['words'].apply(translator.translate)
Negative_Sentiments
# Out:
#                words   weights english_translation
# 153098      enviaram -1.486480               sent
# 264666        passou -1.490242          passed on
# 34507       atrasada -1.490712               late
# 34716         atraso -1.499405              delay
# 145766      entregar -1.506367            deliver
# 107399  decepcionada -1.514798       disappointed
# 123147     diferente -1.515167          different
# 336270        recebi -1.520174         I received
# 239539           nao -1.529595              brain
# 274020       pessima -1.533274           very bad
# 109952        demora -1.619071              delay
# 146251    entregaram -1.643342          delivered
# 9723      aguardando -1.712272            waiting
# 329667      quebrado -1.765645              broke
# 203233  insatisfeita -1.805251        unsatisfied
# 274092       pessimo -1.831116                bad
# 374973         ssima -1.931481              ssima
# 201265      inferior -2.114481              lower
# ...

# %% [markdown]
# #### Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
multinb = MultinomialNB(class_prior=[0.25,0.5])
multinb.fit(X_train, y_train)
param = {'alpha': [1]}

NB = GridSearchCV(multinb, param, cv=2,refit=False,return_train_score=True,scoring='roc_auc')
NB.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=2, estimator=MultinomialNB(class_prior=[0.25, 0.5]),
#              param_grid={'alpha': [1]}, refit=False, return_train_score=True,
#              scoring='roc_auc')

# %%
clf = MultinomialNB(alpha=1 ,class_prior=[0.25,0.5])
clf.fit(X_train, y_train)

#predicted value of y probabilities
y_pred_train = multinb.predict_proba(X_train)
y_pred_test = multinb.predict_proba(X_test)

#predicted values of Y labels
pred_label_train = multinb.predict(X_train)
pred_label_test = multinb.predict(X_test)

# %%
#Get the weights of the words 
nb_weights = pd.DataFrame(list(zip(count_vect.get_feature_names(), 
                                   multinb.coef_[0])), 
                          columns= ['words','weights'])

# %%
Positive_sentiments = pd.DataFrame(lr_weights.sort_values(['weights'], ascending = False)[:20])

# %%
Positive_sentiments['english_translation'] = Positive_sentiments['words'].apply(translator.translate)
Positive_sentiments
# Out:
#                words   weights english_translation
# 166120     excelente  3.256390          Excellent
# 389525          timo  3.172105               Timo
# 275765          pido  2.694402              I ask
# 255753         otimo  2.595993              great
# 17056           amei  2.497577               Amei
# 358938    satisfeito  2.446504            pleased
# 274716          pida  2.442544                ask
# 272397      perfeito  2.415608            Perfect
# 5972          adorei  2.352800         I loved it
# 215217         lindo  2.319936             pretty
# 45931            bom  2.318323               good
# 255509         otima  2.099878              great
# 388676          tima  2.055728               team
# 358400    satisfeita  1.914937          satisfied
# 250613      obrigada  1.884093             thanks
# 252397            ok  1.859842                 ok
# 62098       certinho  1.834610         just right
# 100770  corretamente  1.809469          correctly
# ...

# %%
Negative_Sentiments = pd.DataFrame(nb_weights.sort_values(['weights'], ascending = False)[-20:])

# %%
Negative_Sentiments['english_translation'] = Negative_Sentiments['words'].apply(translator.translate)
Negative_Sentiments
# Out:
#                                words    weights  \
# 173699              faz comprei nada -13.544145
# 173722        faz dias comprei jeito -13.544145
# 173713         faz dias ainda chegou -13.544145
# 173721           faz dias comprei at -13.544145
# 173720        faz dias comprei agora -13.544145
# 173718            faz dias compra at -13.544145
# 173717               faz dias compra -13.544145
# 173716       faz dias chegou produto -13.544145
# 173715         faz dias chegou local -13.544145
# 173714               faz dias chegou -13.544145
# 173712                faz dias ainda -13.544145
# 173700       faz comprei nada enviar -13.544145
# 173710     faz data compra esperando -13.544145
# 173709               faz data compra -13.544145
# 173708                      faz data -13.544145
# 173704          faz comprei site ate -13.544145
# 173703              faz comprei site -13.544145
# 173702  faz comprei produto entregue -13.544145
# ...

# %%
cf_matrix_test = confusion_matrix(y_test,pred_label_test)

# %%
#plot confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cf_matrix_test/np.sum(cf_matrix_test), annot=True,fmt='.2%', cmap='Blues')
plt.show()
